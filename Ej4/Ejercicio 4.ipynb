# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif

# %%
#importación de datos en pandas del archivo sobre ajedrez y carga
data = pd.read_csv('games.csv', )
data
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...

# %%
data['winner']
# Out:
# 0        white
# 1        black
# 2        white
# 3        white
# 4        white
#          ...
# 20053    white
# 20054    black
# 20055    white
# 20056    white
# 20057    black
# Name: winner, Length: 20058, dtype: object

# %%
input_data = data[data.columns[:-1]]
input_data = pd.get_dummies(input_data, prefix=['winner'])
y = data[data.columns[-1]]
input_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 input_data = data[data.columns[:-1]]
# ----> 2 input_data = pd.get_dummies(input_data, prefix=['winner'])
#       3 y = data[data.columns[-1]]
#       4 input_data
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:861, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     854             len_msg = (
#     855                 f"Length of '{name}' ({len(item)}) did not match the "
#     856                 "length of the columns being encoded "
#     857                 f"({data_to_encode.shape[1]})."
#     858             )
#     859             raise ValueError(len_msg)
# --> 861 check_len(prefix, "prefix")
#     862 check_len(prefix_sep, "prefix_sep")
#     864 if isinstance(prefix, str):
#
# ...

# %%
filterKB = SelectKBest(score_func=f_classif, k=5)
filter_model = filterKB.fit(input_data, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 filterKB = SelectKBest(score_func=f_classif, k=5)
# ----> 2 filter_model = filterKB.fit(input_data, y)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/feature_selection/_univariate_selection.py:461, in _BaseFilter.fit(self, X, y)
#     444 def fit(self, X, y):
#     445     """Run score function on (X, y) and get the appropriate features.
#     446
#     447     Parameters
#    (...)
#     459         Returns the instance itself.
#     460     """
# --> 461     X, y = self._validate_data(
#     462         X, y, accept_sparse=["csr", "csc"], multi_output=True
#     463     )
#     465     if not callable(self.score_func):
#     466         raise TypeError(
#     467             "The score function should be a callable, %s (%s) was passed."
# ...

# %%
filter = SelectKBest(score_func=f_classif, k=4)
print(filter)
# Out:
# SelectKBest(k=4)

# %% [markdown]
# 1. Aplica el método Filter de selección de características SelectKBest para conseguir un ranking de importancia de características según los estdísticos pertinentes al tipo de variable

# %%
filter1 = filter.fit(input_data, data['created_at'])
#print(filter_model.scores_)
#selected = filter_model.transform(input_data)
